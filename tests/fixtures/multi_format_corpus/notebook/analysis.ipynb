# %% [markdown]
# # Notebook fixture
#
# A trivial notebook with two markdown and two code cells.

# %%
def hello() -> str:
    return 'hello'

# %% [markdown]
# ## Section
#
# Second markdown cell.

# %%
print(hello())
